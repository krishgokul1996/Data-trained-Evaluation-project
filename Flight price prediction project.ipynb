# %% [markdown]
# # Flight Price Prediction

# %%
import pandas as pd
Flight_Train=pd.read_excel("Flight_Train.xlsx") #reading Flight_Train.xlsx file
Flight_Train.head() #Looking into top 5 rows
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
Flight_Train.shape #Checking the shape of our data
# Out:
# (10683, 11)

# %%
Flight_Train.dtypes #Checking the datatype of each attribute
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %% [markdown]
# As per problem statement Target variable i.e. Price is int64 i.e. continuous. so we'll use Reqression to learn our model.

# %% [markdown]
# ## Handling Null Values

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize = (16,5))
sns.heatmap(Flight_Train.isnull()) #Looking for null values if any, in heatmap
# Out:
# <AxesSubplot:>

# %%
print(Flight_Train.isnull().sum(axis = 0))
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
#Replacing null values with mode becuase the type of objects are object
Flight_Train['Route'].fillna(Flight_Train['Route'].mode()[0], inplace=True)
Flight_Train['Total_Stops'].fillna(Flight_Train['Total_Stops'].mode()[0], inplace=True)

# %%
plt.figure(figsize = (16,5))
sns.heatmap(Flight_Train.isnull()) #Looking for null values if any, in heatmap
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we are performing some feature engineering step for EDA just to get better clearity of data.

# %% [markdown]
# ## Univariate Analysis

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
print(Flight_Train['Source'].value_counts())
plt.figure(figsize = (10,5))
sns.countplot(x="Source", data=Flight_Train)
plt.title("Source of Flight", fontsize = 20)
plt.show()
# Out:
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: Source, dtype: int64

# %% [markdown]
# We can clearly see that Maximum number of Filght Source was Delhi or we can say 4537 Flights source was Delhi.

# %%
print(Flight_Train['Destination'].value_counts())
plt.figure(figsize = (10,5))
sns.countplot(x="Destination", data=Flight_Train)
plt.title("Destination of Flight", fontsize = 20)
plt.show()
# Out:
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: Destination, dtype: int64

# %% [markdown]
# 4537 Flight Destination was Cochin i.e. Maximum

# %%
print(Flight_Train['Total_Stops'].value_counts())
plt.figure(figsize = (10,5))
sns.countplot(x="Total_Stops", data=Flight_Train)
plt.title("Total_Stops of Flight", fontsize = 20)
plt.show()
# Out:
# 1 stop      5626
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %% [markdown]
# Most of the flights were having 1stop i.e. 5626 or 0stops i.e. 3491

# %%
print(Flight_Train['Additional_Info'].value_counts())
plt.figure(figsize = (20,5)) #Plotting with size of 10 * 5
ax=sns.countplot(x="Additional_Info", data=Flight_Train) #Plotting Countplot for Additional_Info
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.title("Additional_Info of Flight", fontsize = 20) #Setting up the title
plt.show() #plotting the graph
# Out:
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
print(Flight_Train['Airline'].value_counts())
plt.figure(figsize = (20,5)) #Plotting with size of 10 * 5
ax=sns.countplot(x="Airline", data=Flight_Train) #Plotting Countplot for Airline
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.title("Airline of Flight", fontsize = 20) #Setting up the title
plt.show() #plotting the graph
# Out:
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: Airline, dtype: int64

# %% [markdown]
# Mostly Jet Airways Airlines Filghts fly in sky.

# %%
Flight_Train['Date_of_Journey'] = pd.to_datetime(Flight_Train['Date_of_Journey'], errors='coerce')
plt.figure(figsize = (20,5))
ax = sns.lineplot(x="Date_of_Journey",y="Price",  data=Flight_Train)
plt.title("Date_of_Journey vs Price", fontsize = 20)
plt.show()

# %%
plt.figure(figsize = (20,10))
ax=sns.boxplot(Flight_Train['Additional_Info'], Flight_Train['Price'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.title('Price vs Additional_Info')
plt.show()

# %% [markdown]
# Note:-
# 1.The Flight price is too low when No check-in baggage were allowed.
# 2.When customer choose Business Class that time Price goes too high.
# 3.When No meal provided in Flight that time flight prices are always lesser than 20,000

# %%
plt.figure(figsize = (20,10))
sns.boxplot(Flight_Train['Source'], Flight_Train['Price'])
plt.title('Price vs Source')
plt.show()

# %% [markdown]
# From Chennai and Mumbai the flights are cheaper as compared with other Sources

# %%
plt.figure(figsize = (20,10))
sns.boxplot(Flight_Train['Destination'], Flight_Train['Price'])
plt.title('Price vs Destination')
plt.show()

# %% [markdown]
# Kolkata, Delhi and Hyderabad flights are cheaper than other Destination price

# %%
plt.figure(figsize = (20,10))
sns.boxplot(Flight_Train['Total_Stops'], Flight_Train['Price'])
plt.title('Price vs Total_Stops')
plt.show()

# %%
plt.figure(figsize = (20,10))
ax=sns.boxplot(Flight_Train['Airline'], Flight_Train['Price'])
ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
plt.title('Price vs Airline')
plt.show()

# %% [markdown]
# Jet Airways flights are always expencive and Spivejet flights are cheaper.
#
# We'll do furter EDA after Feature Engineering and label Encoding

# %% [markdown]
# ## Feature Engineering

# %%
#Checking the unique values will number count.
Flight_Train['Additional_Info'].value_counts()
# Out:
# No info                         8345
# In-flight meal not included     1982
# No check-in baggage included     320
# 1 Long layover                    19
# Change airports                    7
# Business class                     4
# No Info                            3
# 1 Short layover                    1
# Red-eye flight                     1
# 2 Long layover                     1
# Name: Additional_Info, dtype: int64

# %%
#Replacing No Info to No info.
Flight_Train["Additional_Info"]=Flight_Train["Additional_Info"].replace("No Info","No info")

# %%
#Checking the number of Total Stops
Flight_Train['Total_Stops'].value_counts()
# Out:
# 1 stop      5626
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: Total_Stops, dtype: int64

# %%
#Replacing String to numeric for better prediction
Flight_Train.replace({"non-stop": 0, 
                      "1 stop": 1, 
                      "2 stops": 2, 
                      "3 stops": 3, 
                      "4 stops": 4
                     }, inplace = True)

# %%
#Checking value count of stops
Flight_Train['Total_Stops'].value_counts()
# Out:
# 1    5626
# 0    3491
# 2    1520
# 3      45
# 4       1
# Name: Total_Stops, dtype: int64

# %%
#Checking first 5 rows of data
Flight_Train.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration  Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m            0         No info   3897
# 1    05:50         13:15   7h 25m            2         No info   7662
# 2    09:25  04:25 10 Jun      19h            2         No info  13882
# 3    18:05         23:30   5h 25m            1         No info   6218
# 4    16:50         21:35   4h 45m            1         No info  13302

# %%
#Converting Duration from string to numbers
Flight_Train['hour'] = Flight_Train['Duration'].str.split("h").str[0]
Flight_Train['nothing'] = Flight_Train['Duration'].str.split(" ").str[1]
Flight_Train['minute'] = Flight_Train['nothing'].str.split("m").str[0]
Flight_Train.drop('nothing',axis=1,inplace=True)

# %%
Flight_Train['hour'].unique()
# Out:
# array(['2', '7', '19', '5', '4', '15', '21', '25', '13', '12', '26', '22',
#        '23', '20', '10', '6', '11', '8', '16', '3', '27', '1', '14', '9',
#        '18', '17', '24', '30', '28', '29', '37', '34', '38', '35', '36',
#        '47', '33', '32', '31', '42', '39', '5m', '41', '40'], dtype=object)

# %%
for i in range(0,10682):
    if(Flight_Train['hour'][i] == '5m'):
        Flight_Train["hour"][i] = 0
        Flight_Train["minute"][i] = 5

# %%
import numpy as np
Flight_Train['hour'] = pd.to_numeric(Flight_Train['hour']) #Converting object to numeric
Flight_Train['minute'] = pd.to_numeric(Flight_Train['minute']) #Converting object to numeric
Flight_Train['minute']=Flight_Train['minute'].replace(np.NaN,0) #Replacing null values with 0
Flight_Train['minute'] = Flight_Train['minute'].astype('int64') #Converting float to int
Flight_Train['Duration'] = Flight_Train['hour']*60 + Flight_Train['minute'] #Converting hours and minutes into minutes
Flight_Train.drop('hour',axis=1,inplace=True) #Dropping hour becuase work is over
Flight_Train.drop('minute',axis=1,inplace=True) #Dropping minute becuase work is over
Flight_Train.head() #Checking first 5 rows of data
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-01-05   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-09-06     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-12-05   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-01-03  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time  Duration  Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar       170            0         No info   3897
# 1    05:50         13:15       445            2         No info   7662
# 2    09:25  04:25 10 Jun      1140            2         No info  13882
# 3    18:05         23:30       325            1         No info   6218
# 4    16:50         21:35       285            1         No info  13302

# %%
#Converting Departure time into minutes
Flight_Train['Dep_Time'] = pd.to_datetime(Flight_Train['Dep_Time'],format = '%H:%M').dt.hour*60 + pd.to_datetime(Flight_Train['Dep_Time'],format = '%H:%M').dt.minute

# %%
#Converting date into numeric form
import datetime as dt
Flight_Train['Date_of_Journey'] = pd.to_datetime(Flight_Train['Date_of_Journey'])
Flight_Train['Date_of_Journey'] = Flight_Train['Date_of_Journey'].map(dt.datetime.toordinal)
Flight_Train.head() #Checking top 5 rows of dataset
# Out:
#        Airline  Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo           737142  Banglore   New Delhi              BLR → DEL
# 1    Air India           737064   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways           737308     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo           737398   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo           737062  Banglore   New Delhi        BLR → NAG → DEL
#
#    Dep_Time  Arrival_Time  Duration  Total_Stops Additional_Info  Price
# 0      1340  01:10 22 Mar       170            0         No info   3897
# 1       350         13:15       445            2         No info   7662
# 2       565  04:25 10 Jun      1140            2         No info  13882
# 3      1085         23:30       325            1         No info   6218
# 4      1010         21:35       285            1         No info  13302

# %%
#We have Total_Stops columns, So we don't need Route column
#We have Dep_Time and Duration that is equailent to Arrival time, So we don't need it.
Flight_Train.drop('Route',axis=1,inplace=True)
Flight_Train.drop('Arrival_Time',axis=1,inplace=True)

# %%
Flight_Train.head()
# Out:
#        Airline  Date_of_Journey    Source Destination  Dep_Time  Duration  \
# 0       IndiGo           737142  Banglore   New Delhi      1340       170
# 1    Air India           737064   Kolkata    Banglore       350       445
# 2  Jet Airways           737308     Delhi      Cochin       565      1140
# 3       IndiGo           737398   Kolkata    Banglore      1085       325
# 4       IndiGo           737062  Banglore   New Delhi      1010       285
#
#    Total_Stops Additional_Info  Price
# 0            0         No info   3897
# 1            2         No info   7662
# 2            2         No info  13882
# 3            1         No info   6218
# 4            1         No info  13302

# %% [markdown]
# ## Label Encoding

# %%
#Label encoding for the object columns
label_list=list(Flight_Train.select_dtypes(['object']).columns)
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder() #Initlize LabelEncoder to le 
for i in label_list:
    Flight_Train[i] = le.fit_transform(Flight_Train[i])

# %%
#Multivariate Analysis
fig=plt.figure(figsize=(20,10))
hc=Flight_Train.corr(method='pearson')
sns.heatmap(hc,annot=True,cmap="Blues",linewidths=.1, annot_kws={"size": 10})
plt.title("correlation matrix")
plt.show()

# %% [markdown]
# Price is highly corelated with Duration and Total_Stops

# %%
Flight_Train.describe()
# Out:
#             Airline  Date_of_Journey        Source   Destination  \
# count  10683.000000     10683.000000  10683.000000  10683.000000
# mean       3.965927    737208.509033      1.952261      1.436113
# std        2.352155        89.113653      1.177221      1.474782
# min        0.000000    737062.000000      0.000000      0.000000
# 25%        3.000000    737142.000000      2.000000      0.000000
# 50%        4.000000    737203.000000      2.000000      1.000000
# 75%        4.000000    737237.000000      3.000000      2.000000
# max       11.000000    737399.000000      4.000000      5.000000
#
#            Dep_Time      Duration   Total_Stops  Additional_Info         Price
# count  10683.000000  10683.000000  10683.000000     10683.000000  10683.000000
# mean     773.852382    643.093232      0.824207         6.582140   9087.064121
# std      344.964055    507.862001      0.675199         0.838073   4611.359167
# min       20.000000      5.000000      0.000000         0.000000   1759.000000
# 25%      480.000000    170.000000      0.000000         7.000000   5277.000000
# 50%      710.000000    520.000000      1.000000         7.000000   8372.000000
# 75%     1085.000000    930.000000      1.000000         7.000000  12373.000000
# max     1435.000000   2860.000000      4.000000         8.000000  79512.000000

# %% [markdown]
# There is difference between Mean and std of Price of Outliers must be present in it.

# %%
#Correlation with Price with respect to attributes
Flight_Train.corrwith(Flight_Train.Price).plot.bar(
        figsize = (20, 8), title = "Correlation with Price Graph", fontsize = 12,
        rot = 30, grid = True)
# Out:
# <AxesSubplot:title={'center':'Correlation with Price Graph'}>

# %% [markdown]
# As we saw earlier Duration and Total_Stops are heighly corealted with Price

# %% [markdown]
# ## Removing Skewness and Outliers

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(Flight_Train))
print(np.where(z>3))
# Out:
# (array([  123,   226,   396,   402,   486,   510,   553,   597,   628,
#          657,   785,   785,   826,   919,   936,   946,   959,   966,
#          969,   975,  1043,  1067,  1113,  1196,  1218,  1246,  1341,
#         1346,  1424,  1442,  1466,  1478,  1496,  1551,  1629,  1654,
#         1657,  1665,  1712,  1785,  1791,  1804,  1918,  2055,  2079,
#         2099,  2108,  2172,  2172,  2405,  2481,  2495,  2495,  2553,
#         2556,  2556,  2618,  2623,  2633,  2635,  2641,  2654,  2693,
#         2718,  2718,  2814,  2822,  2883,  2924,  2924,  3032,  3032,
#         3111,  3111,  3157,  3220,  3257,  3317,  3400,  3457,  3496,
#         3535,  3535,  3568,  3584,  3700,  3700,  3788,  3790,  3815,
#         3815,  3945,  3966,  4012,  4047,  4118,  4118,  4463,  4463,
#         4521,  4521,  4655,  4655,  4676,  4760,  4829,  5013,  5013,
#         5050,  5136,  5372,  5372,  5439,  5446,  5516,  5628,  5662,
#         5701,  5701,  5710,  5711,  5719,  5738,  5745,  5782,  5838,
#         5856,  5933,  5947,  5953,  5986,  5996,  6024,  6059,  6085,
#         6314,  6321,  6336,  6407,  6444,  6476,  6576,  6576,  6588,
#         6599,  6605,  6884,  6884,  6991,  7001,  7031,  7189,  7232,
#         7249,  7306,  7329,  7351,  7356,  7377,  7537,  7553,  7554,
#         7586,  7611,  7612,  7617,  7713,  7724,  7724,  7752,  7756,
#         7876,  7876,  7902,  7906,  8020,  8080,  8127,  8153,  8153,
#         8204,  8360,  8409,  8412,  8451,  8470,  8536,  8598,  8601,
#         8601,  8621,  8698,  8729,  8729,  8856,  8897,  8940,  8957,
#         8957,  8990,  9019,  9019,  9029,  9182,  9182,  9193,  9239,
#         9247,  9396,  9454,  9479,  9484,  9484,  9551,  9569,  9632,
#         9657,  9673,  9703,  9715,  9848,  9974, 10020, 10052, 10113,
#        10149, 10160, 10182, 10189, 10326, 10353, 10364, 10364, 10383,
#        10439, 10456, 10511, 10511, 10639, 10639], dtype=int64), array([8, 5, 8, 6, 8, 8, 5, 8, 8, 8, 7, 8, 8, 6, 8, 8, 8, 5, 5, 8, 7, 5,
#        5, 8, 6, 8, 8, 5, 8, 5, 8, 8, 5, 5, 8, 8, 5, 6, 7, 8, 5, 5, 8, 8,
#        7, 8, 8, 5, 6, 7, 7, 7, 8, 5, 7, 8, 8, 6, 6, 8, 5, 5, 8, 5, 6, 6,
#        6, 7, 7, 8, 7, 8, 7, 8, 6, 6, 8, 6, 8, 5, 6, 7, 8, 6, 6, 7, 8, 7,
#        5, 5, 6, 6, 5, 8, 5, 5, 6, 5, 6, 7, 8, 5, 6, 8, 6, 8, 7, 8, 6, 8,
#        7, 8, 8, 6, 5, 7, 8, 5, 8, 8, 5, 8, 8, 8, 5, 6, 8, 5, 6, 5, 8, 6,
#        7, 5, 5, 8, 5, 7, 8, 6, 5, 7, 8, 8, 6, 8, 5, 6, 8, 6, 6, 5, 5, 6,
#        5, 5, 8, 8, 8, 8, 5, 8, 6, 5, 5, 8, 8, 7, 8, 6, 8, 5, 6, 8, 5, 8,
#        8, 5, 5, 6, 6, 5, 5, 5, 8, 8, 8, 8, 5, 6, 5, 5, 5, 6, 8, 7, 8, 7,
#        8, 8, 7, 8, 6, 6, 7, 8, 8, 5, 5, 6, 7, 5, 6, 5, 6, 8, 7, 5, 5, 8,
#        5, 8, 5, 8, 8, 7, 8, 8, 8, 5, 8, 7, 8, 8, 8, 5, 7, 8, 5, 6],
#       dtype=int64))

# %%
z=np.abs(zscore(Flight_Train))
threshold=3
new_Flight_Train=Flight_Train[(z<3).all(axis=1)]
print(Flight_Train.shape)
print(new_Flight_Train.shape)
# Out:
# (10683, 9)
# (10475, 9)

# %%
#checking for how much data we lost
loss_percent=(10683-10475)/10683*100
print(loss_percent)
# Out:
# 1.9470186277262942

# %% [markdown]
# We lost almost 2% of our data, which is not bad.

# %%
#Checking skewness of all columns
new_Flight_Train.skew()
# Out:
# Airline            0.730109
# Date_of_Journey    0.486566
# Source            -0.438959
# Destination        1.266475
# Dep_Time           0.113216
# Duration           0.779912
# Total_Stops        0.230633
# Additional_Info   -1.468582
# Price              0.415788
# dtype: float64

# %%
new_Flight_Train.head()
# Out:
#    Airline  Date_of_Journey  Source  Destination  Dep_Time  Duration  \
# 0        3           737142       0            5      1340       170
# 1        1           737064       3            0       350       445
# 2        4           737308       2            1       565      1140
# 3        3           737398       3            0      1085       325
# 4        3           737062       0            5      1010       285
#
#    Total_Stops  Additional_Info  Price
# 0            0                7   3897
# 1            2                7   7662
# 2            2                7  13882
# 3            1                7   6218
# 4            1                7  13302

# %%
#Removing skewness
from sklearn.preprocessing import PowerTransformer
PT=PowerTransformer()
for i in new_Flight_Train.columns:
    if abs(new_Flight_Train.loc[:,i].skew())>0.55:
        new_Flight_Train.loc[:,i]=PT.fit_transform(new_Flight_Train.loc[:,i].values.reshape(-1,1))

# %%
new_Flight_Train.skew()
# Out:
# Airline           -0.013402
# Date_of_Journey    0.486566
# Source            -0.438959
# Destination        0.041017
# Dep_Time           0.113216
# Duration          -0.046552
# Total_Stops        0.230633
# Additional_Info   -1.136146
# Price              0.415788
# dtype: float64

# %% [markdown]
# ## Seperating Input and Output Variables

# %%
y = new_Flight_Train["Price"]
x = new_Flight_Train.drop(["Price"], axis=1)

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scale = MinMaxScaler() #Initializting MinMaxScaler
new = scale.fit(x)  #fitting our data into MinMaxScaller
scale_x = new.transform(x) #Transforming the data
#Setting up the coulumns after Scaling
scaled_x = pd.DataFrame(scale_x, index=x.index, columns=x.columns)
x=scaled_x
x.head() #Priting top 5 rows of our data
# Out:
#     Airline  Date_of_Journey  Source  Destination  Dep_Time  Duration  \
# 0  0.419360         0.237389    0.00     1.000000  0.932862  0.482236
# 1  0.176956         0.005935    0.75     0.000000  0.233216  0.660378
# 2  0.515086         0.729970    0.50     0.440768  0.385159  0.856249
# 3  0.419360         0.997033    0.75     0.000000  0.752650  0.599840
# 4  0.419360         0.000000    0.00     1.000000  0.699647  0.575230
#
#    Total_Stops  Additional_Info
# 0          0.0         0.165293
# 1          1.0         0.165293
# 2          1.0         0.165293
# 3          0.5         0.165293
# 4          0.5         0.165293

# %% [markdown]
# ## Finding Best Random State

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_Score=0
maxRS=0
for i in range(1,1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30,random_state=i)
    LR = LinearRegression()
    LR.fit(x_train, y_train)
    predrf = LR.predict(x_test)
    score = r2_score(y_test, predrf)
    if score>maxR2_Score:
        maxR2_Score=score
        maxRS=i
print("Best accuracy is",maxR2_Score," on Random_state ",maxRS)
# Out:
# Best accuracy is 0.5433243452764488  on Random_state  360

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %%
#importing all the required libraries to find best Algorithm
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score

# %%
model=[LinearRegression(),RandomForestRegressor(),DecisionTreeRegressor(),KNeighborsRegressor(),GradientBoostingRegressor(),Ridge(),SVR()]

# %%
for m in model:
    print("*******************************************************************************")
    print("|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||")
    print('accuracy score of ->', m)
    m.fit(x_train,y_train)
    pred = m.predict(x_test)
    print("R2 Score:                ", r2_score(y_test,pred))
    print("Mean Absolute Error:     ", mean_absolute_error(y_test,pred))
    print("Mean Squared error:      ", mean_squared_error(y_test,pred))
    print("Root Mean Squared Error: ", np.sqrt(mean_squared_error(y_test,pred)))
    score=cross_val_score(m,x,y,cv=8)
    print(score)
    print("cross validation score:  ",score.mean())
    print("Difference between R2 score and cross validatio score is - ",r2_score(y_test,pred)-abs(score.mean()))
    print("|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||")
    print("*******************************************************************************")
# Out:
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> LinearRegression()
# R2 Score:                 0.5433243452764488
# Mean Absolute Error:      2157.0645389788497
# Mean Squared error:       7470645.752834695
# Root Mean Squared Error:  2733.24820549373
# [0.5218934  0.51507901 0.54378328 0.5228583  0.49113157 0.51343271
#  0.48271281 0.5369189 ]
# cross validation score:   0.515976248246264
# Difference between R2 score and cross validatio score is -  0.027348097030184815
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> RandomForestRegressor()
# R2 Score:                 0.8851199167015958
# Mean Absolute Error:      771.3656987902065
# Mean Squared error:       1879295.2886837116
# Root Mean Squared Error:  1370.8739142181207
# [0.88885408 0.90472136 0.89627177 0.88793875 0.87496132 0.88452925
#  0.88526887 0.87696098]
# cross validation score:   0.8874382967544667
# Difference between R2 score and cross validatio score is -  -0.002318380052870883
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> DecisionTreeRegressor()
# R2 Score:                 0.8276995868759538
# Mean Absolute Error:      821.4433131827341
# Mean Squared error:       2818620.472107328
# Root Mean Squared Error:  1678.8747636757566
# [0.81668857 0.84172017 0.81336506 0.83256909 0.80191833 0.8008665
#  0.82978513 0.81766445]
# cross validation score:   0.8193221617456306
# Difference between R2 score and cross validatio score is -  0.008377425130323246
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> KNeighborsRegressor()
# R2 Score:                 0.7579099612721012
# Mean Absolute Error:      1275.641425389755
# Mean Squared error:       3960291.951014954
# Root Mean Squared Error:  1990.0482283138151
# [0.77432135 0.77088439 0.7989919  0.77039909 0.76446026 0.74411146
#  0.74516321 0.75672783]
# cross validation score:   0.7656324369849502
# Difference between R2 score and cross validatio score is -  -0.0077224757128490085
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> GradientBoostingRegressor()
# R2 Score:                 0.8158564740588783
# Mean Absolute Error:      1235.0535622015966
# Mean Squared error:       3012359.0687504676
# Root Mean Squared Error:  1735.6148964417387
# [0.81711833 0.82080217 0.8298909  0.83029614 0.81273099 0.80276785
#  0.81218587 0.81836611]
# cross validation score:   0.818019794930068
# Difference between R2 score and cross validatio score is -  -0.0021633208711897556
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> Ridge()
# R2 Score:                 0.5432707905353087
# Mean Absolute Error:      2157.21681158434
# Mean Squared error:       7471521.841794778
# Root Mean Squared Error:  2733.4084659623736
# [0.52207565 0.51480954 0.54364364 0.52278706 0.49126627 0.51340793
#  0.48270987 0.53708249]
# cross validation score:   0.5159728068760017
# Difference between R2 score and cross validatio score is -  0.027297983659307024
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************
# *******************************************************************************
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# accuracy score of -> SVR()
# R2 Score:                 0.1089793836924835
# Mean Absolute Error:      3164.56907892165
# Mean Squared error:       14575989.138145354
# Root Mean Squared Error:  3817.8513771682306
# [0.14289441 0.1008356  0.12298676 0.12321475 0.12151827 0.14127857
#  0.13084478 0.13082065]
# cross validation score:   0.1267992226985708
# Difference between R2 score and cross validatio score is -  -0.0178198390060873
# |||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# *******************************************************************************

# %% [markdown]
# Random Forest Regressor model have heighest accuracy i.e. 88.59% with 88.77% cross validation score which is good and the difference is too less.

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = {"max_depth":range(21,25),
              "criterion":['mse'],
              "max_features": ['auto', 'sqrt'],
              "min_samples_leaf":range(1,5)}

clf = GridSearchCV(RandomForestRegressor(), parameters)
clf.fit(x_train,y_train) #fitting train and test data
clf.best_params_  #Best parameters
# Out:
# {'criterion': 'mse',
#  'max_depth': 23,
#  'max_features': 'auto',
#  'min_samples_leaf': 1}

# %%
clf_pred=clf.best_estimator_.predict(x_test)

r2_score(y_test, clf_pred)
# Out:
# 0.8849103951336631

# %% [markdown]
# Our model learnt Almost 89% .

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(clf.best_estimator_,"PJ7_Flight.obj")
RF_from_joblib=joblib.load('PJ7_Flight.obj')
Predicted = RF_from_joblib.predict(x_test)
Predicted
# Out:
# array([10623.18      , 10076.15485714, 12358.99      , ...,
#         7671.78133333,  9454.62773049,  4925.25      ])

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
pd.DataFrame([RF_from_joblib.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
# Out:
#                0             1         2        3        4        5     \
# Predicted  10623.18  10076.154857  12358.99  3334.58  6490.64  5848.65
# Original    5567.00   8372.000000  12898.00  3210.00  6093.00  5073.00
#
#                6             7        8         9       10      11       12    \
# Predicted  12438.68  12331.757812  8570.72  14712.24  7229.0  5174.1  6051.72
# Original   13663.00  13504.000000  9187.00  14781.00  7229.0  4668.0  5386.00
#
#                13        14        15            16       17      18    \
# Predicted  12420.78  10124.73  17033.67  11725.099048  3438.02  5077.5
# Original   12395.00  11410.00  15025.00  11668.000000  4392.00  5613.0
#
#               19            20        21       22       23           24    \
# Predicted  6670.04  10663.399316  7184.622  7807.86  5915.16  7453.171333
# Original   8040.00   9001.000000  5126.000  7832.00  6961.00  8851.000000
#
#                   25       26       27           28        29       30    \
# Predicted  4633.013947   9225.4  5464.72  4607.176206  13248.89  6130.97
# Original   4823.000000  10203.0  5228.00  4823.000000  13364.00  5963.00
#
#               31       32           33       34      35       36        37    \
# Predicted  9073.85  6954.49  8653.461967  12898.0  7229.0  12898.0   9255.96
# Original   8147.00  6860.00  6795.000000  12898.0  7229.0  12898.0  10696.00
#
#                   38        39           40       41           42       43    \
# Predicted  4713.644625  12773.21  9618.335648  5491.95  4284.533026  16231.2
# Original   4804.000000  11467.00  8601.000000  5201.00  4174.000000  16289.0
#
#               44       45           46        47          48         49    \
# Predicted  5816.45  7394.27  3677.471143  15107.85  15029.5175  12247.655
# Original   6934.00  7229.00  3597.000000  15129.00  15129.0000   7198.000
#
#                   50       51         52            53      54      55    \
# Predicted  8914.804917  3842.64  12055.572  12414.371429  5369.4  7064.0
# Original   6513.000000  3841.00   9417.000  12646.000000  4544.0  7064.0
#
#                56           57       58       59           60           61    \
# Predicted  8645.085  9708.191523  11102.9  11230.3  4302.069926  8351.091795
# Original   8728.000  6645.000000  11087.0   9134.0  4488.000000  7258.000000
#
#               62        63        64      65          66       67    \
# Predicted  5283.78  17109.26  10670.95  3807.0  11998.4534  5994.89
# Original   4544.00  17261.00  10441.00  3807.0  12093.0000  4483.00
#
#                    68       69       70       71        72       73    \
